# %%
import pandas as pd
import datetime
import csv
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
plt.style.use('ggplot')

# %% [markdown]
# ## Comparación Deep Learning vs Identidad vs ORB+RANSAC+OpenCV

# %%
plt.style.use('ggplot')
df = pd.read_csv('resultados_experimentos_2.csv')
ax = df.plot.bar(x='Model', y='mace', rot=20, figsize=(10,5))

# %% [markdown]
# ## Comparación del modelo con batch normalization y dropout variando el rho

# %%
plt.style.use('ggplot')
df = pd.read_csv('resultados_experimentos.csv')
df_rho_experiment = df.loc[df['model'] == "with_dropout_batch_norm"]
ax = df_rho_experiment.plot.bar(x='rho', y='mace', rot=0, figsize=(10,5))

# %% [markdown]
# ## Comparación con/sin dropout y batch normalization

# %%
plt.style.use('ggplot')
df = pd.read_csv('resultados_experimentos.csv')
df_rho_experiment = df.loc[df['rho'] == 32]
ax = df_rho_experiment.plot.bar(x='model', y='mace', rot=0, figsize=(10,5))

# %% [markdown]
# ## Experimento transfer learning

# %%
# Using numpy we can use the function loadtxt to load your CSV file.
# We ignore the first line with the column names and use ',' as a delimiter.
data = np.loadtxt('experimento_transfer_learning.csv', delimiter=',', skiprows=1)

['Epoch', 'mace', 'val_mace']

epoch = data[:,0]
mace = data[:,1]
val_mace = data[:,2]

fig, ax = plt.subplots(figsize=(10,10))

# train
ax.plot(epoch, mace, 'green',label='Training MACE')
ax.plot(epoch, val_mace, 'red',label='Validation MACE')

# Show the legend
plt.legend()
